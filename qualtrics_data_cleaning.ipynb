# %%
import pandas as pd
import re

# %% [markdown]
# ### The screening question were already scanned and participants were filtered based on responses manually to remove unauthentic, erroneous and incomplete responses. Here we will directly proceed to the cleaning of data.

# %% [markdown]
# ### Read csv

# %%
df = pd.read_csv("qualtrics_data.csv")

# %% [markdown]
# ### Combine list of unused columns

# %%
columns_to_drop = [
    "StartDate",
    "EndDate",
    "Status",
    "IPAddress",
    "RecordedDate",
    "RecipientLastName",
    "RecipientFirstName",
    "RecipientEmail",
    "ExternalReference",
    "LocationLatitude",
    "LocationLongitude",
    "DistributionChannel",
    "UserLanguage",
    "consent",
    "combination",
    "priorExperience",
    "Q111",
    "Q24",
    "Q25",
]

# %% [markdown]
# ### Drop unused columns

# %%
df = df.drop(columns_to_drop, axis=1)

# %% [markdown]
# ### Drop duplicate ResponseId

# %%
df = df.drop(df.iloc[:, [66]], axis=1)

# %% [markdown]
# ### Create list of columns for renaming

# %%
rename_columns = {
    "Q93_1":"t3_1",
    "Q93_2":"t3_2",
    "Q93_3":"t3_3",
    "Q93_4":"t3_4",
    "Q98_1":"t6_1",
    "Q98_2":"t6_2",
    "Q98_3":"t6_3",
    "Q98_4":"t6_4",
    "Q99_1":"t9_1",
    "Q99_2":"t9_2",
    "Q99_3":"t9_3",
    "Q99_4":"t9_4",
    "Q100_1":"t12_1",
    "Q100_2":"t12_2",
    "Q100_3":"t12_3",
    "Q100_4":"t12_4",
    "Q101_1":"t15_1",
    "Q101_2":"t15_2",
    "Q101_3":"t15_3",
    "Q101_4":"t15_4",
    "Q102_1":"t18_1",
    "Q102_2":"t18_2",
    "Q102_3":"t18_3",
    "Q102_4":"t18_4",
    "Q103_1":"t21_1",
    "Q103_2":"t21_2",
    "Q103_3":"t21_3",
    "Q103_4":"t21_4",
    "Q104_1":"t24_1",
    "Q104_2":"t24_2",
    "Q104_3":"t24_3",
    "Q104_4":"t24_4",
    "Q105_1":"t27_1",
    "Q105_2":"t27_2",
    "Q105_3":"t27_3",
    "Q105_4":"t27_4",
    "Q106_1":"t30_1",
    "Q106_2":"t30_2",
    "Q106_3":"t30_3",
    "Q106_4":"t30_4",
    "Q107_1":"t33_1",
    "Q107_2":"t33_2",
    "Q107_3":"t33_3",
    "Q107_4":"t33_4",
    "Q108_1": "t36_1",
    "Q108_2": "t36_2",
    "Q108_3": "t36_3",
    "Q108_4": "t36_4",
    "feature_usefullness_1" : "sidebar_rating",
    "feature_usefullness_2" : "categorization_rating",
    "feature_usefullness_3" : "category_sidebar_rating"
}

# %% [markdown]
# ### Rename the columns

# %%
df = df.rename(rename_columns, axis=1)

# %% [markdown]
# ### Drop 1st two rows containing redundant data(question test, import id)

# %%
df = df.drop(df.index[0:2])

# %% [markdown]
# ### Combine list of columns to change the data type

# %%
correct_dtypes = {
    "t3_1": float,
    "t3_2": float,
    "t3_3": float,
    "t3_4": float,
    "t6_1": float,
    "t6_2": float,
    "t6_3": float,
    "t6_4": float,
    "t9_1": float,
    "t9_2": float,
    "t9_3": float,
    "t9_4": float,
    "t12_1":float,
    "t12_2":float,
    "t12_3":float,
    "t12_4":float,
    "t15_1":float,
    "t15_2":float,
    "t15_3":float,
    "t15_4":float,
    "t18_1":float,
    "t18_2":float,
    "t18_3":float,
    "t18_4":float,
    "t21_1":float,
    "t21_2":float,
    "t21_3":float,
    "t21_4":float,
    "t24_1":float,
    "t24_2":float,
    "t24_3":float,
    "t24_4":float,
    "t27_1":float,
    "t27_2":float,
    "t27_3":float,
    "t27_4":float,
    "t30_1":float,
    "t30_2":float,
    "t30_3":float,
    "t30_4":float,
    "t33_1":float,
    "t33_2":float,
    "t33_3":float,
    "t33_4":float,
    "t36_1":float,
    "t36_2":float,
    "t36_3":float,
    "t36_4":float,
    "sidebar_rating":float,
    "categorization_rating":float,
    "category_sidebar_rating":float
}

# %% [markdown]
# ### Change the data type

# %%
df = df.astype(correct_dtypes)

# %% [markdown]
# ### Create functions to combine the 4 questions for ease_of_use using System Usability Scale method

# %%
def process_t3(row):
    if row.IV1 == "fixed-sidebar":
        #return 2.5*( (row.t3_1+4-1) + (7 - row.t3_2 - 4) + (row.t3_3 + 4-1) + (7 - row.t3_4 - 4) )
        return (row.t3_1, row.t3_2, row.t3_3, row.t3_4)
    else:
        return None
    
def process_t6(row):
    if row.IV1 == "fixed-sidebar":
        #return 2.5*( (row.t6_1 + 4 - 1) + (7 - row.t6_2 - 4) + (row.t6_3 + 4 - 1) + (7 - row.t6_4 - 4) )
        return (row.t6_1, row.t6_2, row.t6_3, row.t6_4)
    else:
        return None

def process_t9(row):
    if row.IV1 == "fixed-sidebar":
        #return 2.5*( (row.t9_1+4-1) + (7 - row.t9_2 - 4) + (row.t9_3 + 4 -1) + (7 - row.t9_4 - 4) )
        return (row.t9_1, row.t9_2, row.t9_3, row.t9_4)
    else:
        return None
        
def process_t12(row):
    print(row)
    if row.IV1 == "fixed-sidebar":
        #return 2.5*( (row.t12_1 + 4 -1) + (7 - row.t12_2 - 4) + (row.t12_3 + 4 -1) + (7 - row.t12_4 - 4) )
        return (row.t12_1, row.t12_2, row.t12_3, row.t12_4)
    else:
        return None
    
def process_t15(row):
    if row.IV1 == "fixed-sidebar":
        #return 2.5*( (row.t15_1 + 4 -1) + (7 - row.t15_2 - 4) + (row.t15_3 + 4 -1) + (7 - row.t15_4 - 4) )
        return (row.t15_1, row.t15_2, row.t15_3, row.t15_4)
    else:
        return None
    
def process_t18(row):
    print(row)
    if row.IV1 == "fixed-sidebar":
        #return 2.5*( (row.t18_1 + 4 -1) + (7 - row.t18_2 - 4) + (row.t18_3 + 4 -1) + (7 - row.t18_4 - 4) )
        return (row.t18_1, row.t18_2, row.t18_3, row.t18_4)
    else:
        return None

def process_t21(row):
    if row.IV1 == "floating-sidebar":
        return (row.t21_1, row.t21_2, row.t21_3, row.t21_4)
        #return 2.5*( (row.t21_1 + 4 -1) + (7 - row.t21_2 - 4) + (row.t21_3 + 4 -1) + (7 - row.t21_4 - 4) )
    else:
        return None
    
def process_t24(row):
    if row.IV1 == "floating-sidebar":
        return (row.t24_1, row.t24_2, row.t24_3, row.t24_4)
        #return 2.5*( (row.t24_1 + 4 -1) + (7 - row.t24_2 - 4) + (row.t24_3 + 4 -1) + (7 - row.t24_4 - 4) )
    else:
        return None

def process_t27(row):
    if row.IV1 == "floating-sidebar":
        return (row.t27_1, row.t27_2, row.t27_3, row.t27_4)
        #return 2.5*( (row.t27_1 + 4 -1) + (7 - row.t27_2 - 4) + (row.t27_3 + 4 -1) + (7 - row.t27_4 - 4) )
    else:
        return None
        
def process_t30(row):
    if row.IV1 == "floating-sidebar":
        return (row.t30_1, row.t30_2, row.t30_3, row.t30_4)
        #return 2.5*( (row.t30_1 + 4 -1) + (7 - row.t30_2 - 4) + (row.t30_3 + 4 -1) + (7 - row.t30_4 - 4) )
    else:
        return None
    
def process_t33(row):
    if row.IV1 == "floating-sidebar":
        return (row.t33_1, row.t33_2, row.t33_3, row.t33_4)
        #return 2.5*( (row.t33_1 + 4 -1) + (7 - row.t33_2 - 4) + (row.t33_3 + 4 -1) + (7 - row.t33_4 - 4) )
    else:
        return None
    
def process_t36(row):
    if row.IV1 == "floating-sidebar":
        return (row.t36_1, row.t36_2, row.t36_3, row.t36_4)
        #return 2.5*( (row.t36_1 + 4 -1) + (7 - row.t36_2 - 4) + (row.t36_3 + 4 -1) + (7 - row.t36_4 - 4) )
    else:
        return None

# %% [markdown]
# ### Apply the previous methods to trial question and combine them together into 1 metric
# ### Questions were asked after every 3 trials, so broadcast the same answers for previous 2 trials

# %%
df["t3"] = df.apply(lambda row: process_t3(row), axis=1)
df["t1"] = df.apply(lambda row:row.t3, axis=1)
df["t2"] = df.apply(lambda row:row.t3, axis=1)

df["t6"] = df.apply(lambda row: process_t6(row), axis=1)
df["t4"] = df.apply(lambda row:row.t6, axis=1)
df["t5"] = df.apply(lambda row:row.t6, axis=1)

df["t9"] = df.apply(lambda row: process_t9(row), axis=1)
df["t7"] = df.apply(lambda row:row.t9, axis=1)
df["t8"] = df.apply(lambda row:row.t9, axis=1)

df["t12"] = df.apply(lambda row: process_t12(row), axis=1)
df["t10"] = df.apply(lambda row:row.t12, axis=1)
df["t11"] = df.apply(lambda row:row.t12, axis=1)

df["t15"] = df.apply(lambda row: process_t15(row), axis=1)
df["t13"] = df.apply(lambda row:row.t15, axis=1)
df["t14"] = df.apply(lambda row:row.t15, axis=1)

df["t18"] = df.apply(lambda row: process_t18(row), axis=1)
df["t16"] = df.apply(lambda row:row.t18, axis=1)
df["t17"] = df.apply(lambda row:row.t18, axis=1)

df["t21"] = df.apply(lambda row: process_t21(row), axis=1)
df["t19"] = df.apply(lambda row:row.t21, axis=1)
df["t20"] = df.apply(lambda row:row.t21, axis=1)

df["t24"] = df.apply(lambda row: process_t24(row), axis=1)
df["t22"] = df.apply(lambda row:row.t24, axis=1)
df["t23"] = df.apply(lambda row:row.t24, axis=1)

df["t27"] = df.apply(lambda row: process_t27(row), axis=1)
df["t25"] = df.apply(lambda row:row.t27, axis=1)
df["t26"] = df.apply(lambda row:row.t27, axis=1)

df["t30"] = df.apply(lambda row: process_t30(row), axis=1)
df["t28"] = df.apply(lambda row:row.t30, axis=1)
df["t29"] = df.apply(lambda row:row.t30, axis=1)

df["t33"] = df.apply(lambda row: process_t33(row), axis=1)
df["t31"] = df.apply(lambda row:row.t33, axis=1)
df["t32"] = df.apply(lambda row:row.t33, axis=1)

df["t36"] = df.apply(lambda row: process_t36(row), axis=1)
df["t34"] = df.apply(lambda row:row.t36, axis=1)
df["t35"] = df.apply(lambda row:row.t36, axis=1)
# Out:
# Progress                               100
# Duration (in seconds)                  565
# Finished                                 1
# ResponseId               R_1jg3libD6KGk9H6
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 2, Length: 78, dtype: object
# Progress                                  100
# Duration (in seconds)                     100
# Finished                                    1
# ResponseId                  R_28J2ielzrCfvy71
# pri_exp                                     1
#                                  ...
# t4                       (1.0, 2.0, 2.0, 2.0)
# t5                       (1.0, 2.0, 2.0, 2.0)
# t9                       (3.0, 2.0, 2.0, 1.0)
# t7                       (3.0, 2.0, 2.0, 1.0)
# t8                       (3.0, 2.0, 2.0, 1.0)
# Name: 3, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  920
# Finished                                 1
# ResponseId               R_1q1Bu2t44LidHJ7
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 4, Length: 78, dtype: object
# Progress                                    100
# Duration (in seconds)                       852
# Finished                                      1
# ResponseId                    R_1lsl8kCjFiBTyzK
# pri_exp                                       1
#                                   ...
# t4                         (3.0, 3.0, 3.0, 3.0)
# t5                         (3.0, 3.0, 3.0, 3.0)
# t9                       (3.0, -3.0, -3.0, 3.0)
# t7                       (3.0, -3.0, -3.0, 3.0)
# t8                       (3.0, -3.0, -3.0, 3.0)
# Name: 5, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  674
# Finished                                 1
# ResponseId               R_2QuIZZlVUGCBNnT
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 6, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                 1053
# Finished                                 1
# ResponseId               R_RXEQ1CVWS1G26uB
# pri_exp                                  2
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 7, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                   56
# Finished                                 1
# ResponseId               R_3n15rM0puihW0As
# pri_exp                                  2
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 8, Length: 78, dtype: object
# Progress                                  100
# Duration (in seconds)                    1598
# Finished                                    1
# ResponseId                  R_UfKVwc8Ysy6pN1n
# pri_exp                                     1
#                                  ...
# t4                       (2.0, 2.0, 2.0, 2.0)
# t5                       (2.0, 2.0, 2.0, 2.0)
# t9                       (1.0, 2.0, 0.0, 1.0)
# t7                       (1.0, 2.0, 0.0, 1.0)
# t8                       (1.0, 2.0, 0.0, 1.0)
# Name: 9, Length: 78, dtype: object
# Progress                                  100
# Duration (in seconds)                    3717
# Finished                                    1
# ResponseId                  R_1cTAX495KgNw4zW
# pri_exp                                     1
#                                  ...
# t4                       (1.0, 1.0, 2.0, 1.0)
# t5                       (1.0, 1.0, 2.0, 1.0)
# t9                       (1.0, 1.0, 0.0, 1.0)
# t7                       (1.0, 1.0, 0.0, 1.0)
# t8                       (1.0, 1.0, 0.0, 1.0)
# Name: 10, Length: 78, dtype: object
# Progress                                   100
# Duration (in seconds)                     5756
# Finished                                     1
# ResponseId                   R_3hDv6lQBiaJSbmx
# pri_exp                                      1
#                                  ...
# t4                       (1.0, 2.0, -2.0, 1.0)
# t5                       (1.0, 2.0, -2.0, 1.0)
# t9                       (2.0, 2.0, -1.0, 2.0)
# t7                       (2.0, 2.0, -1.0, 2.0)
# t8                       (2.0, 2.0, -1.0, 2.0)
# Name: 11, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  906
# Finished                                 1
# ResponseId               R_3r0MPrhyKAiN456
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 12, Length: 78, dtype: object
# Progress                                      100
# Duration (in seconds)                         975
# Finished                                        1
# ResponseId                      R_3JaYb1pOqZxJWjR
# pri_exp                                         1
#                                    ...
# t4                          (0.0, 0.0, -1.0, 0.0)
# t5                          (0.0, 0.0, -1.0, 0.0)
# t9                       (-2.0, -2.0, -2.0, -2.0)
# t7                       (-2.0, -2.0, -2.0, -2.0)
# t8                       (-2.0, -2.0, -2.0, -2.0)
# Name: 13, Length: 78, dtype: object
# Progress                                    100
# Duration (in seconds)                       819
# Finished                                      1
# ResponseId                    R_4GvYKPN7O7VmLE5
# pri_exp                                       1
#                                   ...
# t4                         (2.0, 2.0, 2.0, 2.0)
# t5                         (2.0, 2.0, 2.0, 2.0)
# t9                       (1.0, -1.0, -1.0, 2.0)
# t7                       (1.0, -1.0, -1.0, 2.0)
# t8                       (1.0, -1.0, -1.0, 2.0)
# Name: 14, Length: 78, dtype: object
# Progress                                   100
# Duration (in seconds)                    57702
# Finished                                     1
# ResponseId                   R_BVzB1em5zins9Ed
# pri_exp                                      1
#                                  ...
# t4                        (3.0, 3.0, 3.0, 3.0)
# t5                        (3.0, 3.0, 3.0, 3.0)
# t9                       (0.0, 0.0, -1.0, 0.0)
# t7                       (0.0, 0.0, -1.0, 0.0)
# t8                       (0.0, 0.0, -1.0, 0.0)
# Name: 15, Length: 78, dtype: object
# Progress                                     100
# Duration (in seconds)                       4084
# Finished                                       1
# ResponseId                     R_3JEPAzSSS7vl7m8
# pri_exp                                        1
#                                   ...
# t4                         (1.0, -2.0, 1.0, 2.0)
# t5                         (1.0, -2.0, 1.0, 2.0)
# t9                       (1.0, -2.0, -2.0, -1.0)
# t7                       (1.0, -2.0, -2.0, -1.0)
# t8                       (1.0, -2.0, -2.0, -1.0)
# Name: 16, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                   74
# Finished                                 1
# ResponseId               R_1DVdutmeC595uTS
# pri_exp                                  2
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 17, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  990
# Finished                                 1
# ResponseId               R_pMA85t7Mv3uCvZv
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 18, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  523
# Finished                                 1
# ResponseId               R_3lrDJAYNb7HdI4g
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 19, Length: 78, dtype: object
# Progress                                      100
# Duration (in seconds)                         610
# Finished                                        1
# ResponseId                      R_R9rAxbkMUkt1JD3
# pri_exp                                         1
#                                    ...
# t4                       (-3.0, -3.0, -3.0, -3.0)
# t5                       (-3.0, -3.0, -3.0, -3.0)
# t9                       (-3.0, -3.0, -3.0, -3.0)
# t7                       (-3.0, -3.0, -3.0, -3.0)
# t8                       (-3.0, -3.0, -3.0, -3.0)
# Name: 20, Length: 78, dtype: object
# Progress                                      100
# Duration (in seconds)                       80204
# Finished                                        1
# ResponseId                      R_2Ug3SEeklouMcjf
# pri_exp                                         1
#                                    ...
# t4                           (2.0, 2.0, 2.0, 2.0)
# t5                           (2.0, 2.0, 2.0, 2.0)
# t9                       (-2.0, -2.0, -2.0, -2.0)
# t7                       (-2.0, -2.0, -2.0, -2.0)
# t8                       (-2.0, -2.0, -2.0, -2.0)
# Name: 21, Length: 78, dtype: object
# Progress                                   100
# Duration (in seconds)                      728
# Finished                                     1
# ResponseId                   R_0wWEN41ItvEhPq1
# pri_exp                                      1
#                                  ...
# t4                       (0.0, -1.0, 1.0, 0.0)
# t5                       (0.0, -1.0, 1.0, 0.0)
# t9                        (0.0, 0.0, 1.0, 1.0)
# t7                        (0.0, 0.0, 1.0, 1.0)
# t8                        (0.0, 0.0, 1.0, 1.0)
# Name: 22, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  848
# Finished                                 1
# ResponseId               R_prv1eb7fdBytdwB
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 23, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  553
# Finished                                 1
# ResponseId               R_1rqdXQIUzMSPgaI
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 24, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  192
# Finished                                 1
# ResponseId               R_3PRbWLDIxLDwycw
# pri_exp                                  2
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 25, Length: 78, dtype: object
# Progress                                  100
# Duration (in seconds)                     802
# Finished                                    1
# ResponseId                  R_1diRg3FdvVeuFW3
# pri_exp                                     1
#                                  ...
# t4                       (3.0, 1.0, 3.0, 2.0)
# t5                       (3.0, 1.0, 3.0, 2.0)
# t9                       (2.0, 1.0, 3.0, 2.0)
# t7                       (2.0, 1.0, 3.0, 2.0)
# t8                       (2.0, 1.0, 3.0, 2.0)
# Name: 26, Length: 78, dtype: object
# Progress                                  100
# Duration (in seconds)                     641
# Finished                                    1
# ResponseId                  R_x41neWaLb6waSPf
# pri_exp                                     1
#                                  ...
# t4                       (2.0, 2.0, 2.0, 2.0)
# t5                       (2.0, 2.0, 2.0, 2.0)
# t9                       (2.0, 2.0, 1.0, 1.0)
# t7                       (2.0, 2.0, 1.0, 1.0)
# t8                       (2.0, 2.0, 1.0, 1.0)
# Name: 27, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  385
# Finished                                 1
# ResponseId               R_sFoJmEO3bd10x9f
# pri_exp                                  1
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 28, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  117
# Finished                                 1
# ResponseId               R_uyt6pwGxKMQiUIV
# pri_exp                                  2
#                                ...
# t4                                    None
# t5                                    None
# t9                                    None
# t7                                    None
# t8                                    None
# Name: 29, Length: 78, dtype: object
# Progress                                  100
# Duration (in seconds)                     502
# Finished                                    1
# ResponseId                  R_1FA0BdICJQM8hHO
# pri_exp                                     1
#                                  ...
# t4                       (2.0, 2.0, 2.0, 2.0)
# t5                       (2.0, 2.0, 2.0, 2.0)
# t9                       (2.0, 2.0, 2.0, 2.0)
# t7                       (2.0, 2.0, 2.0, 2.0)
# t8                       (2.0, 2.0, 2.0, 2.0)
# Name: 30, Length: 78, dtype: object
# Progress                               100
# Duration (in seconds)                  565
# Finished                                 1
# ResponseId               R_1jg3libD6KGk9H6
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 2, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                     100
# Finished                                    1
# ResponseId                  R_28J2ielzrCfvy71
# pri_exp                                     1
#                                  ...
# t10                      (2.0, 2.0, 1.0, 0.0)
# t11                      (2.0, 2.0, 1.0, 0.0)
# t15                      (3.0, 2.0, 1.0, 1.0)
# t13                      (3.0, 2.0, 1.0, 1.0)
# t14                      (3.0, 2.0, 1.0, 1.0)
# Name: 3, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  920
# Finished                                 1
# ResponseId               R_1q1Bu2t44LidHJ7
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 4, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                     852
# Finished                                    1
# ResponseId                  R_1lsl8kCjFiBTyzK
# pri_exp                                     1
#                                  ...
# t10                      (3.0, 3.0, 3.0, 3.0)
# t11                      (3.0, 3.0, 3.0, 3.0)
# t15                      (3.0, 3.0, 3.0, 3.0)
# t13                      (3.0, 3.0, 3.0, 3.0)
# t14                      (3.0, 3.0, 3.0, 3.0)
# Name: 5, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  674
# Finished                                 1
# ResponseId               R_2QuIZZlVUGCBNnT
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 6, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                 1053
# Finished                                 1
# ResponseId               R_RXEQ1CVWS1G26uB
# pri_exp                                  2
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 7, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                   56
# Finished                                 1
# ResponseId               R_3n15rM0puihW0As
# pri_exp                                  2
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 8, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                    1598
# Finished                                    1
# ResponseId                  R_UfKVwc8Ysy6pN1n
# pri_exp                                     1
#                                  ...
# t10                      (2.0, 2.0, 2.0, 2.0)
# t11                      (2.0, 2.0, 2.0, 2.0)
# t15                      (2.0, 2.0, 2.0, 2.0)
# t13                      (2.0, 2.0, 2.0, 2.0)
# t14                      (2.0, 2.0, 2.0, 2.0)
# Name: 9, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                    3717
# Finished                                    1
# ResponseId                  R_1cTAX495KgNw4zW
# pri_exp                                     1
#                                  ...
# t10                      (1.0, 1.0, 2.0, 1.0)
# t11                      (1.0, 1.0, 2.0, 1.0)
# t15                      (2.0, 1.0, 2.0, 2.0)
# t13                      (2.0, 1.0, 2.0, 2.0)
# t14                      (2.0, 1.0, 2.0, 2.0)
# Name: 10, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                    5756
# Finished                                    1
# ResponseId                  R_3hDv6lQBiaJSbmx
# pri_exp                                     1
#                                  ...
# t10                      (2.0, 3.0, 2.0, 3.0)
# t11                      (2.0, 3.0, 2.0, 3.0)
# t15                      (2.0, 2.0, 2.0, 3.0)
# t13                      (2.0, 2.0, 2.0, 3.0)
# t14                      (2.0, 2.0, 2.0, 3.0)
# Name: 11, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  906
# Finished                                 1
# ResponseId               R_3r0MPrhyKAiN456
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 12, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                     975
# Finished                                    1
# ResponseId                  R_3JaYb1pOqZxJWjR
# pri_exp                                     1
#                                  ...
# t10                      (0.0, 0.0, 0.0, 0.0)
# t11                      (0.0, 0.0, 0.0, 0.0)
# t15                      (1.0, 1.0, 1.0, 1.0)
# t13                      (1.0, 1.0, 1.0, 1.0)
# t14                      (1.0, 1.0, 1.0, 1.0)
# Name: 13, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                     819
# Finished                                    1
# ResponseId                  R_4GvYKPN7O7VmLE5
# pri_exp                                     1
#                                  ...
# t10                      (2.0, 2.0, 2.0, 2.0)
# t11                      (2.0, 2.0, 2.0, 2.0)
# t15                      (2.0, 3.0, 3.0, 3.0)
# t13                      (2.0, 3.0, 3.0, 3.0)
# t14                      (2.0, 3.0, 3.0, 3.0)
# Name: 14, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                   57702
# Finished                                    1
# ResponseId                  R_BVzB1em5zins9Ed
# pri_exp                                     1
#                                  ...
# t10                      (2.0, 2.0, 2.0, 2.0)
# t11                      (2.0, 2.0, 2.0, 2.0)
# t15                      (3.0, 3.0, 3.0, 3.0)
# t13                      (3.0, 3.0, 3.0, 3.0)
# t14                      (3.0, 3.0, 3.0, 3.0)
# Name: 15, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                    4084
# Finished                                    1
# ResponseId                  R_3JEPAzSSS7vl7m8
# pri_exp                                     1
#                                  ...
# t10                      (2.0, 2.0, 2.0, 2.0)
# t11                      (2.0, 2.0, 2.0, 2.0)
# t15                      (1.0, 1.0, 1.0, 2.0)
# t13                      (1.0, 1.0, 1.0, 2.0)
# t14                      (1.0, 1.0, 1.0, 2.0)
# Name: 16, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                   74
# Finished                                 1
# ResponseId               R_1DVdutmeC595uTS
# pri_exp                                  2
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 17, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  990
# Finished                                 1
# ResponseId               R_pMA85t7Mv3uCvZv
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 18, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  523
# Finished                                 1
# ResponseId               R_3lrDJAYNb7HdI4g
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 19, Length: 84, dtype: object
# Progress                                      100
# Duration (in seconds)                         610
# Finished                                        1
# ResponseId                      R_R9rAxbkMUkt1JD3
# pri_exp                                         1
#                                    ...
# t10                      (-2.0, -2.0, -3.0, -2.0)
# t11                      (-2.0, -2.0, -3.0, -2.0)
# t15                       (-1.0, -1.0, 0.0, -1.0)
# t13                       (-1.0, -1.0, 0.0, -1.0)
# t14                       (-1.0, -1.0, 0.0, -1.0)
# Name: 20, Length: 84, dtype: object
# Progress                                      100
# Duration (in seconds)                       80204
# Finished                                        1
# ResponseId                      R_2Ug3SEeklouMcjf
# pri_exp                                         1
#                                    ...
# t10                      (-1.0, -1.0, -1.0, -1.0)
# t11                      (-1.0, -1.0, -1.0, -1.0)
# t15                          (1.0, 1.0, 1.0, 1.0)
# t13                          (1.0, 1.0, 1.0, 1.0)
# t14                          (1.0, 1.0, 1.0, 1.0)
# Name: 21, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                     728
# Finished                                    1
# ResponseId                  R_0wWEN41ItvEhPq1
# pri_exp                                     1
#                                  ...
# t10                      (1.0, 1.0, 1.0, 1.0)
# t11                      (1.0, 1.0, 1.0, 1.0)
# t15                      (1.0, 1.0, 1.0, 1.0)
# t13                      (1.0, 1.0, 1.0, 1.0)
# t14                      (1.0, 1.0, 1.0, 1.0)
# Name: 22, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  848
# Finished                                 1
# ResponseId               R_prv1eb7fdBytdwB
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 23, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  553
# Finished                                 1
# ResponseId               R_1rqdXQIUzMSPgaI
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 24, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  192
# Finished                                 1
# ResponseId               R_3PRbWLDIxLDwycw
# pri_exp                                  2
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 25, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                     802
# Finished                                    1
# ResponseId                  R_1diRg3FdvVeuFW3
# pri_exp                                     1
#                                  ...
# t10                      (1.0, 1.0, 1.0, 1.0)
# t11                      (1.0, 1.0, 1.0, 1.0)
# t15                      (2.0, 1.0, 2.0, 1.0)
# t13                      (2.0, 1.0, 2.0, 1.0)
# t14                      (2.0, 1.0, 2.0, 1.0)
# Name: 26, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                     641
# Finished                                    1
# ResponseId                  R_x41neWaLb6waSPf
# pri_exp                                     1
#                                  ...
# t10                      (2.0, 2.0, 2.0, 2.0)
# t11                      (2.0, 2.0, 2.0, 2.0)
# t15                      (2.0, 2.0, 2.0, 2.0)
# t13                      (2.0, 2.0, 2.0, 2.0)
# t14                      (2.0, 2.0, 2.0, 2.0)
# Name: 27, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  385
# Finished                                 1
# ResponseId               R_sFoJmEO3bd10x9f
# pri_exp                                  1
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 28, Length: 84, dtype: object
# Progress                               100
# Duration (in seconds)                  117
# Finished                                 1
# ResponseId               R_uyt6pwGxKMQiUIV
# pri_exp                                  2
#                                ...
# t10                                   None
# t11                                   None
# t15                                   None
# t13                                   None
# t14                                   None
# Name: 29, Length: 84, dtype: object
# Progress                                  100
# Duration (in seconds)                     502
# Finished                                    1
# ResponseId                  R_1FA0BdICJQM8hHO
# pri_exp                                     1
#                                  ...
# t10                      (2.0, 2.0, 2.0, 2.0)
# t11                      (2.0, 2.0, 2.0, 2.0)
# t15                      (2.0, 2.0, 2.0, 2.0)
# t13                      (2.0, 2.0, 2.0, 2.0)
# t14                      (2.0, 2.0, 2.0, 2.0)
# Name: 30, Length: 84, dtype: object

# %% [markdown]
# ### Drop the individual columns for each question since their data has been combined into 1 single column

# %%
drop_t_columns = {
"t3_1",
"t3_2",
"t3_3",
"t3_4",
"t6_1",
"t6_2",
"t6_3",
"t6_4",
"t9_1",
"t9_2",
"t9_3",
"t9_4",
"t12_1",
"t12_2",
"t12_3",
"t12_4",
"t15_1",
"t15_2",
"t15_3",
"t15_4",
"t18_1",
"t18_2",
"t18_3",
"t18_4",
"t21_1",
"t21_2",
"t21_3",
"t21_4",
"t24_1",
"t24_2",
"t24_3",
"t24_4",
"t27_1",
"t27_2",
"t27_3",
"t27_4",
"t30_1",
"t30_2",
"t30_3",
"t30_4",
"t33_1",
"t33_2",
"t33_3",
"t33_4",
"t36_1",
"t36_2",
"t36_3",
"t36_4"
}

# %%
df = df.drop(drop_t_columns, axis=1)

# %% [markdown]
# ### Drop some more unused columns

# %%
df = df.drop(["platform","Duration (in seconds)"], axis=1)

# %% [markdown]
# ### Convert from wide to long form

# %%
df2 = pd.melt(df, id_vars=["Progress", "Finished","ResponseId","pri_exp","buy_check","browser_check","task_check","age_group","gender","computer_use_confide","sweet_food_affinity","computer_os","sidebar_rating","categorization_rating","category_sidebar_rating","IV1","arrangement","sequence" ,"ecomm_frequence"  ], value_vars = ["t1","t2","t3","t4","t5","t6","t7","t8","t9","t10","t11","t12","t13","t14","t15","t16","t17","t18","t19","t21","t22","t23","t24","t25","t26","t27","t28","t29","t30","t31","t32","t33","t34","t35","t36"], var_name="trial_id",value_name='ease_of_use')

# %% [markdown]
# ### Remove the rows with NA in ease_of_use column

# %%
df3 = df2[df2['ease_of_use'].notna()]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423 entries, 1 to 1012
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Progress                 423 non-null    object
#  1   Finished                 423 non-null    object
#  2   ResponseId               423 non-null    object
#  3   pri_exp                  423 non-null    object
#  4   buy_check                423 non-null    object
#  5   browser_check            423 non-null    object
#  6   task_check               423 non-null    object
#  7   age_group                423 non-null    object
#  8   gender                   423 non-null    object
#  9   computer_use_confide     423 non-null    object
#  10  sweet_food_affinity      423 non-null    object
#  11  computer_os              423 non-null    object
#  12  sidebar_rating           423 non-null    float64
#  13  categorization_rating    423 non-null    float64
#  14  category_sidebar_rating  423 non-null    float64
#  15  IV1                      423 non-null    object
#  16  arrangement              423 non-null    object
#  17  sequence                 423 non-null    object
#  18  ecomm_frequence          423 non-null    object
#  19  trial_id                 423 non-null    object
#  20  ease_of_use              423 non-null    object
# dtypes: float64(3), object(18)
# memory usage: 72.7+ KB

# %% [markdown]
# ### Remove some more unused columns

# %%
df3 = df3.drop(["Progress","Finished","task_check","browser_check","sequence"], axis=1)

# %% [markdown]
# ### Convert data type of trial_id columns to int

# %%
df3["trial_id"] = df3["trial_id"].str.replace(r'\D+', '').astype('int')
# Out:
# <ipython-input-20-7e6a4762c9ee>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df3["trial_id"] = df3["trial_id"].str.replace(r'\D+', '').astype('int')

# %% [markdown]
# ### Function for getting the level of IV2 and IV3 using the trial_id

# %%
def make_iv2(row):
    if any(lower<=row.trial_id<=upper for (lower, upper) in [(1,3), (10,12),(19,21),(28,30)]):
        return "right_sidebar_no_categorization"
    elif any(lower<=row.trial_id<=upper for (lower, upper) in [(8,9), (16,18),(25,27),(34,26)]):
        return "no_right_sidebar_no_categorization"
    else:
        return "right_sidebar_categorization"

def make_iv3(row):
    if any(lower<=row.trial_id<=upper for (lower, upper) in [(1,9), (19,27)]):
        return "6-cupcakes"
    else:
        return "3-cupcakes"

# %% [markdown]
# ### Apply the functions previously defined to create columns for IV2 and IV3

# %%
df3["IV2"] = df3.apply(lambda row:make_iv2(row),axis=1)
df3["IV3"] = df3.apply(lambda row:make_iv3(row),axis=1)

# %%
print(df3[["ResponseId","IV1","IV2","IV3","trial_id","ease_of_use"]].to_string())
# Out:
#              ResponseId               IV1                                 IV2         IV3  trial_id               ease_of_use
# 1     R_28J2ielzrCfvy71     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (0.0, 1.0, 2.0, 3.0)
# 3     R_1lsl8kCjFiBTyzK     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (3.0, 1.0, 1.0, 1.0)
# 7     R_UfKVwc8Ysy6pN1n     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (2.0, 1.0, 1.0, 1.0)
# 8     R_1cTAX495KgNw4zW     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (1.0, 2.0, 2.0, 1.0)
# 9     R_3hDv6lQBiaJSbmx     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1     (2.0, 2.0, -1.0, 3.0)
# 11    R_3JaYb1pOqZxJWjR     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1    (0.0, -1.0, -1.0, 0.0)
# 12    R_4GvYKPN7O7VmLE5     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (2.0, 2.0, 2.0, 2.0)
# 13    R_BVzB1em5zins9Ed     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (1.0, 1.0, 1.0, 1.0)
# 14    R_3JEPAzSSS7vl7m8     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (1.0, 1.0, 1.0, 1.0)
# 18    R_R9rAxbkMUkt1JD3     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1  (-3.0, -3.0, -3.0, -3.0)
# 19    R_2Ug3SEeklouMcjf     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (1.0, 1.0, 1.0, 1.0)
# 20    R_0wWEN41ItvEhPq1     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (1.0, 1.0, 1.0, 1.0)
# 24    R_1diRg3FdvVeuFW3     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (2.0, 1.0, 2.0, 2.0)
# 25    R_x41neWaLb6waSPf     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (2.0, 2.0, 2.0, 2.0)
# 28    R_1FA0BdICJQM8hHO     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         1      (2.0, 2.0, 2.0, 2.0)
# 30    R_28J2ielzrCfvy71     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (0.0, 1.0, 2.0, 3.0)
# 32    R_1lsl8kCjFiBTyzK     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (3.0, 1.0, 1.0, 1.0)
# 36    R_UfKVwc8Ysy6pN1n     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (2.0, 1.0, 1.0, 1.0)
# 37    R_1cTAX495KgNw4zW     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (1.0, 2.0, 2.0, 1.0)
# 38    R_3hDv6lQBiaJSbmx     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2     (2.0, 2.0, -1.0, 3.0)
# 40    R_3JaYb1pOqZxJWjR     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2    (0.0, -1.0, -1.0, 0.0)
# 41    R_4GvYKPN7O7VmLE5     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (2.0, 2.0, 2.0, 2.0)
# 42    R_BVzB1em5zins9Ed     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (1.0, 1.0, 1.0, 1.0)
# 43    R_3JEPAzSSS7vl7m8     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (1.0, 1.0, 1.0, 1.0)
# 47    R_R9rAxbkMUkt1JD3     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2  (-3.0, -3.0, -3.0, -3.0)
# 48    R_2Ug3SEeklouMcjf     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (1.0, 1.0, 1.0, 1.0)
# 49    R_0wWEN41ItvEhPq1     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (1.0, 1.0, 1.0, 1.0)
# 53    R_1diRg3FdvVeuFW3     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (2.0, 1.0, 2.0, 2.0)
# 54    R_x41neWaLb6waSPf     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (2.0, 2.0, 2.0, 2.0)
# 57    R_1FA0BdICJQM8hHO     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         2      (2.0, 2.0, 2.0, 2.0)
# 59    R_28J2ielzrCfvy71     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (0.0, 1.0, 2.0, 3.0)
# 61    R_1lsl8kCjFiBTyzK     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (3.0, 1.0, 1.0, 1.0)
# 65    R_UfKVwc8Ysy6pN1n     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (2.0, 1.0, 1.0, 1.0)
# 66    R_1cTAX495KgNw4zW     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (1.0, 2.0, 2.0, 1.0)
# 67    R_3hDv6lQBiaJSbmx     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3     (2.0, 2.0, -1.0, 3.0)
# 69    R_3JaYb1pOqZxJWjR     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3    (0.0, -1.0, -1.0, 0.0)
# 70    R_4GvYKPN7O7VmLE5     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (2.0, 2.0, 2.0, 2.0)
# 71    R_BVzB1em5zins9Ed     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (1.0, 1.0, 1.0, 1.0)
# 72    R_3JEPAzSSS7vl7m8     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (1.0, 1.0, 1.0, 1.0)
# 76    R_R9rAxbkMUkt1JD3     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3  (-3.0, -3.0, -3.0, -3.0)
# 77    R_2Ug3SEeklouMcjf     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (1.0, 1.0, 1.0, 1.0)
# 78    R_0wWEN41ItvEhPq1     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (1.0, 1.0, 1.0, 1.0)
# 82    R_1diRg3FdvVeuFW3     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (2.0, 1.0, 2.0, 2.0)
# 83    R_x41neWaLb6waSPf     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (2.0, 2.0, 2.0, 2.0)
# 86    R_1FA0BdICJQM8hHO     fixed-sidebar     right_sidebar_no_categorization  6-cupcakes         3      (2.0, 2.0, 2.0, 2.0)
# 88    R_28J2ielzrCfvy71     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (1.0, 2.0, 2.0, 2.0)
# 90    R_1lsl8kCjFiBTyzK     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (3.0, 3.0, 3.0, 3.0)
# 94    R_UfKVwc8Ysy6pN1n     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (2.0, 2.0, 2.0, 2.0)
# 95    R_1cTAX495KgNw4zW     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (1.0, 1.0, 2.0, 1.0)
# 96    R_3hDv6lQBiaJSbmx     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4     (1.0, 2.0, -2.0, 1.0)
# 98    R_3JaYb1pOqZxJWjR     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4     (0.0, 0.0, -1.0, 0.0)
# 99    R_4GvYKPN7O7VmLE5     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (2.0, 2.0, 2.0, 2.0)
# 100   R_BVzB1em5zins9Ed     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (3.0, 3.0, 3.0, 3.0)
# 101   R_3JEPAzSSS7vl7m8     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4     (1.0, -2.0, 1.0, 2.0)
# 105   R_R9rAxbkMUkt1JD3     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4  (-3.0, -3.0, -3.0, -3.0)
# 106   R_2Ug3SEeklouMcjf     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (2.0, 2.0, 2.0, 2.0)
# 107   R_0wWEN41ItvEhPq1     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4     (0.0, -1.0, 1.0, 0.0)
# 111   R_1diRg3FdvVeuFW3     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (3.0, 1.0, 3.0, 2.0)
# 112   R_x41neWaLb6waSPf     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (2.0, 2.0, 2.0, 2.0)
# 115   R_1FA0BdICJQM8hHO     fixed-sidebar        right_sidebar_categorization  6-cupcakes         4      (2.0, 2.0, 2.0, 2.0)
# 117   R_28J2ielzrCfvy71     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (1.0, 2.0, 2.0, 2.0)
# 119   R_1lsl8kCjFiBTyzK     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (3.0, 3.0, 3.0, 3.0)
# 123   R_UfKVwc8Ysy6pN1n     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (2.0, 2.0, 2.0, 2.0)
# 124   R_1cTAX495KgNw4zW     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (1.0, 1.0, 2.0, 1.0)
# 125   R_3hDv6lQBiaJSbmx     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5     (1.0, 2.0, -2.0, 1.0)
# 127   R_3JaYb1pOqZxJWjR     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5     (0.0, 0.0, -1.0, 0.0)
# 128   R_4GvYKPN7O7VmLE5     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (2.0, 2.0, 2.0, 2.0)
# 129   R_BVzB1em5zins9Ed     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (3.0, 3.0, 3.0, 3.0)
# 130   R_3JEPAzSSS7vl7m8     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5     (1.0, -2.0, 1.0, 2.0)
# 134   R_R9rAxbkMUkt1JD3     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5  (-3.0, -3.0, -3.0, -3.0)
# 135   R_2Ug3SEeklouMcjf     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (2.0, 2.0, 2.0, 2.0)
# 136   R_0wWEN41ItvEhPq1     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5     (0.0, -1.0, 1.0, 0.0)
# 140   R_1diRg3FdvVeuFW3     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (3.0, 1.0, 3.0, 2.0)
# 141   R_x41neWaLb6waSPf     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (2.0, 2.0, 2.0, 2.0)
# 144   R_1FA0BdICJQM8hHO     fixed-sidebar        right_sidebar_categorization  6-cupcakes         5      (2.0, 2.0, 2.0, 2.0)
# 146   R_28J2ielzrCfvy71     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (1.0, 2.0, 2.0, 2.0)
# 148   R_1lsl8kCjFiBTyzK     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (3.0, 3.0, 3.0, 3.0)
# 152   R_UfKVwc8Ysy6pN1n     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (2.0, 2.0, 2.0, 2.0)
# 153   R_1cTAX495KgNw4zW     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (1.0, 1.0, 2.0, 1.0)
# 154   R_3hDv6lQBiaJSbmx     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6     (1.0, 2.0, -2.0, 1.0)
# 156   R_3JaYb1pOqZxJWjR     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6     (0.0, 0.0, -1.0, 0.0)
# 157   R_4GvYKPN7O7VmLE5     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (2.0, 2.0, 2.0, 2.0)
# 158   R_BVzB1em5zins9Ed     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (3.0, 3.0, 3.0, 3.0)
# 159   R_3JEPAzSSS7vl7m8     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6     (1.0, -2.0, 1.0, 2.0)
# 163   R_R9rAxbkMUkt1JD3     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6  (-3.0, -3.0, -3.0, -3.0)
# 164   R_2Ug3SEeklouMcjf     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (2.0, 2.0, 2.0, 2.0)
# 165   R_0wWEN41ItvEhPq1     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6     (0.0, -1.0, 1.0, 0.0)
# 169   R_1diRg3FdvVeuFW3     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (3.0, 1.0, 3.0, 2.0)
# 170   R_x41neWaLb6waSPf     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (2.0, 2.0, 2.0, 2.0)
# 173   R_1FA0BdICJQM8hHO     fixed-sidebar        right_sidebar_categorization  6-cupcakes         6      (2.0, 2.0, 2.0, 2.0)
# 175   R_28J2ielzrCfvy71     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7      (3.0, 2.0, 2.0, 1.0)
# 177   R_1lsl8kCjFiBTyzK     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7    (3.0, -3.0, -3.0, 3.0)
# 181   R_UfKVwc8Ysy6pN1n     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7      (1.0, 2.0, 0.0, 1.0)
# 182   R_1cTAX495KgNw4zW     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7      (1.0, 1.0, 0.0, 1.0)
# 183   R_3hDv6lQBiaJSbmx     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7     (2.0, 2.0, -1.0, 2.0)
# 185   R_3JaYb1pOqZxJWjR     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7  (-2.0, -2.0, -2.0, -2.0)
# 186   R_4GvYKPN7O7VmLE5     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7    (1.0, -1.0, -1.0, 2.0)
# 187   R_BVzB1em5zins9Ed     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7     (0.0, 0.0, -1.0, 0.0)
# 188   R_3JEPAzSSS7vl7m8     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7   (1.0, -2.0, -2.0, -1.0)
# 192   R_R9rAxbkMUkt1JD3     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7  (-3.0, -3.0, -3.0, -3.0)
# 193   R_2Ug3SEeklouMcjf     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7  (-2.0, -2.0, -2.0, -2.0)
# 194   R_0wWEN41ItvEhPq1     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7      (0.0, 0.0, 1.0, 1.0)
# 198   R_1diRg3FdvVeuFW3     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7      (2.0, 1.0, 3.0, 2.0)
# 199   R_x41neWaLb6waSPf     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7      (2.0, 2.0, 1.0, 1.0)
# 202   R_1FA0BdICJQM8hHO     fixed-sidebar        right_sidebar_categorization  6-cupcakes         7      (2.0, 2.0, 2.0, 2.0)
# 204   R_28J2ielzrCfvy71     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8      (3.0, 2.0, 2.0, 1.0)
# 206   R_1lsl8kCjFiBTyzK     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8    (3.0, -3.0, -3.0, 3.0)
# 210   R_UfKVwc8Ysy6pN1n     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8      (1.0, 2.0, 0.0, 1.0)
# 211   R_1cTAX495KgNw4zW     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8      (1.0, 1.0, 0.0, 1.0)
# 212   R_3hDv6lQBiaJSbmx     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8     (2.0, 2.0, -1.0, 2.0)
# 214   R_3JaYb1pOqZxJWjR     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8  (-2.0, -2.0, -2.0, -2.0)
# 215   R_4GvYKPN7O7VmLE5     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8    (1.0, -1.0, -1.0, 2.0)
# 216   R_BVzB1em5zins9Ed     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8     (0.0, 0.0, -1.0, 0.0)
# 217   R_3JEPAzSSS7vl7m8     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8   (1.0, -2.0, -2.0, -1.0)
# 221   R_R9rAxbkMUkt1JD3     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8  (-3.0, -3.0, -3.0, -3.0)
# 222   R_2Ug3SEeklouMcjf     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8  (-2.0, -2.0, -2.0, -2.0)
# 223   R_0wWEN41ItvEhPq1     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8      (0.0, 0.0, 1.0, 1.0)
# 227   R_1diRg3FdvVeuFW3     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8      (2.0, 1.0, 3.0, 2.0)
# 228   R_x41neWaLb6waSPf     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8      (2.0, 2.0, 1.0, 1.0)
# 231   R_1FA0BdICJQM8hHO     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         8      (2.0, 2.0, 2.0, 2.0)
# 233   R_28J2ielzrCfvy71     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9      (3.0, 2.0, 2.0, 1.0)
# 235   R_1lsl8kCjFiBTyzK     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9    (3.0, -3.0, -3.0, 3.0)
# 239   R_UfKVwc8Ysy6pN1n     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9      (1.0, 2.0, 0.0, 1.0)
# 240   R_1cTAX495KgNw4zW     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9      (1.0, 1.0, 0.0, 1.0)
# 241   R_3hDv6lQBiaJSbmx     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9     (2.0, 2.0, -1.0, 2.0)
# 243   R_3JaYb1pOqZxJWjR     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9  (-2.0, -2.0, -2.0, -2.0)
# 244   R_4GvYKPN7O7VmLE5     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9    (1.0, -1.0, -1.0, 2.0)
# 245   R_BVzB1em5zins9Ed     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9     (0.0, 0.0, -1.0, 0.0)
# 246   R_3JEPAzSSS7vl7m8     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9   (1.0, -2.0, -2.0, -1.0)
# 250   R_R9rAxbkMUkt1JD3     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9  (-3.0, -3.0, -3.0, -3.0)
# 251   R_2Ug3SEeklouMcjf     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9  (-2.0, -2.0, -2.0, -2.0)
# 252   R_0wWEN41ItvEhPq1     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9      (0.0, 0.0, 1.0, 1.0)
# 256   R_1diRg3FdvVeuFW3     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9      (2.0, 1.0, 3.0, 2.0)
# 257   R_x41neWaLb6waSPf     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9      (2.0, 2.0, 1.0, 1.0)
# 260   R_1FA0BdICJQM8hHO     fixed-sidebar  no_right_sidebar_no_categorization  6-cupcakes         9      (2.0, 2.0, 2.0, 2.0)
# 262   R_28J2ielzrCfvy71     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (2.0, 2.0, 1.0, 0.0)
# 264   R_1lsl8kCjFiBTyzK     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (3.0, 3.0, 3.0, 3.0)
# 268   R_UfKVwc8Ysy6pN1n     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (2.0, 2.0, 2.0, 2.0)
# 269   R_1cTAX495KgNw4zW     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (1.0, 1.0, 2.0, 1.0)
# 270   R_3hDv6lQBiaJSbmx     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (2.0, 3.0, 2.0, 3.0)
# 272   R_3JaYb1pOqZxJWjR     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (0.0, 0.0, 0.0, 0.0)
# 273   R_4GvYKPN7O7VmLE5     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (2.0, 2.0, 2.0, 2.0)
# 274   R_BVzB1em5zins9Ed     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (2.0, 2.0, 2.0, 2.0)
# 275   R_3JEPAzSSS7vl7m8     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (2.0, 2.0, 2.0, 2.0)
# 279   R_R9rAxbkMUkt1JD3     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10  (-2.0, -2.0, -3.0, -2.0)
# 280   R_2Ug3SEeklouMcjf     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10  (-1.0, -1.0, -1.0, -1.0)
# 281   R_0wWEN41ItvEhPq1     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (1.0, 1.0, 1.0, 1.0)
# 285   R_1diRg3FdvVeuFW3     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (1.0, 1.0, 1.0, 1.0)
# 286   R_x41neWaLb6waSPf     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (2.0, 2.0, 2.0, 2.0)
# 289   R_1FA0BdICJQM8hHO     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        10      (2.0, 2.0, 2.0, 2.0)
# 291   R_28J2ielzrCfvy71     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (2.0, 2.0, 1.0, 0.0)
# 293   R_1lsl8kCjFiBTyzK     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (3.0, 3.0, 3.0, 3.0)
# 297   R_UfKVwc8Ysy6pN1n     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (2.0, 2.0, 2.0, 2.0)
# 298   R_1cTAX495KgNw4zW     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (1.0, 1.0, 2.0, 1.0)
# 299   R_3hDv6lQBiaJSbmx     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (2.0, 3.0, 2.0, 3.0)
# 301   R_3JaYb1pOqZxJWjR     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (0.0, 0.0, 0.0, 0.0)
# 302   R_4GvYKPN7O7VmLE5     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (2.0, 2.0, 2.0, 2.0)
# 303   R_BVzB1em5zins9Ed     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (2.0, 2.0, 2.0, 2.0)
# 304   R_3JEPAzSSS7vl7m8     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (2.0, 2.0, 2.0, 2.0)
# 308   R_R9rAxbkMUkt1JD3     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11  (-2.0, -2.0, -3.0, -2.0)
# 309   R_2Ug3SEeklouMcjf     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11  (-1.0, -1.0, -1.0, -1.0)
# 310   R_0wWEN41ItvEhPq1     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (1.0, 1.0, 1.0, 1.0)
# 314   R_1diRg3FdvVeuFW3     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (1.0, 1.0, 1.0, 1.0)
# 315   R_x41neWaLb6waSPf     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (2.0, 2.0, 2.0, 2.0)
# 318   R_1FA0BdICJQM8hHO     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        11      (2.0, 2.0, 2.0, 2.0)
# 320   R_28J2ielzrCfvy71     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (2.0, 2.0, 1.0, 0.0)
# 322   R_1lsl8kCjFiBTyzK     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (3.0, 3.0, 3.0, 3.0)
# 326   R_UfKVwc8Ysy6pN1n     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (2.0, 2.0, 2.0, 2.0)
# 327   R_1cTAX495KgNw4zW     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (1.0, 1.0, 2.0, 1.0)
# 328   R_3hDv6lQBiaJSbmx     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (2.0, 3.0, 2.0, 3.0)
# 330   R_3JaYb1pOqZxJWjR     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (0.0, 0.0, 0.0, 0.0)
# 331   R_4GvYKPN7O7VmLE5     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (2.0, 2.0, 2.0, 2.0)
# 332   R_BVzB1em5zins9Ed     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (2.0, 2.0, 2.0, 2.0)
# 333   R_3JEPAzSSS7vl7m8     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (2.0, 2.0, 2.0, 2.0)
# 337   R_R9rAxbkMUkt1JD3     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12  (-2.0, -2.0, -3.0, -2.0)
# 338   R_2Ug3SEeklouMcjf     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12  (-1.0, -1.0, -1.0, -1.0)
# 339   R_0wWEN41ItvEhPq1     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (1.0, 1.0, 1.0, 1.0)
# 343   R_1diRg3FdvVeuFW3     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (1.0, 1.0, 1.0, 1.0)
# 344   R_x41neWaLb6waSPf     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (2.0, 2.0, 2.0, 2.0)
# 347   R_1FA0BdICJQM8hHO     fixed-sidebar     right_sidebar_no_categorization  3-cupcakes        12      (2.0, 2.0, 2.0, 2.0)
# 349   R_28J2ielzrCfvy71     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (3.0, 2.0, 1.0, 1.0)
# 351   R_1lsl8kCjFiBTyzK     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (3.0, 3.0, 3.0, 3.0)
# 355   R_UfKVwc8Ysy6pN1n     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (2.0, 2.0, 2.0, 2.0)
# 356   R_1cTAX495KgNw4zW     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (2.0, 1.0, 2.0, 2.0)
# 357   R_3hDv6lQBiaJSbmx     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (2.0, 2.0, 2.0, 3.0)
# 359   R_3JaYb1pOqZxJWjR     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (1.0, 1.0, 1.0, 1.0)
# 360   R_4GvYKPN7O7VmLE5     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (2.0, 3.0, 3.0, 3.0)
# 361   R_BVzB1em5zins9Ed     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (3.0, 3.0, 3.0, 3.0)
# 362   R_3JEPAzSSS7vl7m8     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (1.0, 1.0, 1.0, 2.0)
# 366   R_R9rAxbkMUkt1JD3     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13   (-1.0, -1.0, 0.0, -1.0)
# 367   R_2Ug3SEeklouMcjf     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (1.0, 1.0, 1.0, 1.0)
# 368   R_0wWEN41ItvEhPq1     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (1.0, 1.0, 1.0, 1.0)
# 372   R_1diRg3FdvVeuFW3     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (2.0, 1.0, 2.0, 1.0)
# 373   R_x41neWaLb6waSPf     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (2.0, 2.0, 2.0, 2.0)
# 376   R_1FA0BdICJQM8hHO     fixed-sidebar        right_sidebar_categorization  3-cupcakes        13      (2.0, 2.0, 2.0, 2.0)
# 378   R_28J2ielzrCfvy71     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (3.0, 2.0, 1.0, 1.0)
# 380   R_1lsl8kCjFiBTyzK     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (3.0, 3.0, 3.0, 3.0)
# 384   R_UfKVwc8Ysy6pN1n     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (2.0, 2.0, 2.0, 2.0)
# 385   R_1cTAX495KgNw4zW     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (2.0, 1.0, 2.0, 2.0)
# 386   R_3hDv6lQBiaJSbmx     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (2.0, 2.0, 2.0, 3.0)
# 388   R_3JaYb1pOqZxJWjR     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (1.0, 1.0, 1.0, 1.0)
# 389   R_4GvYKPN7O7VmLE5     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (2.0, 3.0, 3.0, 3.0)
# 390   R_BVzB1em5zins9Ed     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (3.0, 3.0, 3.0, 3.0)
# 391   R_3JEPAzSSS7vl7m8     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (1.0, 1.0, 1.0, 2.0)
# 395   R_R9rAxbkMUkt1JD3     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14   (-1.0, -1.0, 0.0, -1.0)
# 396   R_2Ug3SEeklouMcjf     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (1.0, 1.0, 1.0, 1.0)
# 397   R_0wWEN41ItvEhPq1     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (1.0, 1.0, 1.0, 1.0)
# 401   R_1diRg3FdvVeuFW3     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (2.0, 1.0, 2.0, 1.0)
# 402   R_x41neWaLb6waSPf     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (2.0, 2.0, 2.0, 2.0)
# 405   R_1FA0BdICJQM8hHO     fixed-sidebar        right_sidebar_categorization  3-cupcakes        14      (2.0, 2.0, 2.0, 2.0)
# 407   R_28J2ielzrCfvy71     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (3.0, 2.0, 1.0, 1.0)
# 409   R_1lsl8kCjFiBTyzK     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (3.0, 3.0, 3.0, 3.0)
# 413   R_UfKVwc8Ysy6pN1n     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (2.0, 2.0, 2.0, 2.0)
# 414   R_1cTAX495KgNw4zW     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (2.0, 1.0, 2.0, 2.0)
# 415   R_3hDv6lQBiaJSbmx     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (2.0, 2.0, 2.0, 3.0)
# 417   R_3JaYb1pOqZxJWjR     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (1.0, 1.0, 1.0, 1.0)
# 418   R_4GvYKPN7O7VmLE5     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (2.0, 3.0, 3.0, 3.0)
# 419   R_BVzB1em5zins9Ed     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (3.0, 3.0, 3.0, 3.0)
# 420   R_3JEPAzSSS7vl7m8     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (1.0, 1.0, 1.0, 2.0)
# 424   R_R9rAxbkMUkt1JD3     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15   (-1.0, -1.0, 0.0, -1.0)
# 425   R_2Ug3SEeklouMcjf     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (1.0, 1.0, 1.0, 1.0)
# 426   R_0wWEN41ItvEhPq1     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (1.0, 1.0, 1.0, 1.0)
# 430   R_1diRg3FdvVeuFW3     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (2.0, 1.0, 2.0, 1.0)
# 431   R_x41neWaLb6waSPf     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (2.0, 2.0, 2.0, 2.0)
# 434   R_1FA0BdICJQM8hHO     fixed-sidebar        right_sidebar_categorization  3-cupcakes        15      (2.0, 2.0, 2.0, 2.0)
# 436   R_28J2ielzrCfvy71     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16      (3.0, 2.0, 1.0, 0.0)
# 438   R_1lsl8kCjFiBTyzK     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16    (-3.0, -3.0, 0.0, 0.0)
# 442   R_UfKVwc8Ysy6pN1n     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16      (2.0, 2.0, 2.0, 2.0)
# 443   R_1cTAX495KgNw4zW     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16  (-2.0, -1.0, -2.0, -1.0)
# 444   R_3hDv6lQBiaJSbmx     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16      (2.0, 2.0, 2.0, 3.0)
# 446   R_3JaYb1pOqZxJWjR     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16  (-1.0, -1.0, -1.0, -1.0)
# 447   R_4GvYKPN7O7VmLE5     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16      (2.0, 2.0, 2.0, 2.0)
# 448   R_BVzB1em5zins9Ed     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16      (2.0, 2.0, 2.0, 2.0)
# 449   R_3JEPAzSSS7vl7m8     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16     (1.0, -1.0, 1.0, 2.0)
# 453   R_R9rAxbkMUkt1JD3     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16  (-2.0, -2.0, -3.0, -2.0)
# 454   R_2Ug3SEeklouMcjf     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16  (-2.0, -2.0, -2.0, -2.0)
# 455   R_0wWEN41ItvEhPq1     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16      (1.0, 1.0, 1.0, 1.0)
# 459   R_1diRg3FdvVeuFW3     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16     (0.0, 1.0, -2.0, 1.0)
# 460   R_x41neWaLb6waSPf     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16      (2.0, 2.0, 1.0, 1.0)
# 463   R_1FA0BdICJQM8hHO     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        16      (2.0, 2.0, 2.0, 2.0)
# 465   R_28J2ielzrCfvy71     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17      (3.0, 2.0, 1.0, 0.0)
# 467   R_1lsl8kCjFiBTyzK     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17    (-3.0, -3.0, 0.0, 0.0)
# 471   R_UfKVwc8Ysy6pN1n     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17      (2.0, 2.0, 2.0, 2.0)
# 472   R_1cTAX495KgNw4zW     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17  (-2.0, -1.0, -2.0, -1.0)
# 473   R_3hDv6lQBiaJSbmx     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17      (2.0, 2.0, 2.0, 3.0)
# 475   R_3JaYb1pOqZxJWjR     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17  (-1.0, -1.0, -1.0, -1.0)
# 476   R_4GvYKPN7O7VmLE5     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17      (2.0, 2.0, 2.0, 2.0)
# 477   R_BVzB1em5zins9Ed     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17      (2.0, 2.0, 2.0, 2.0)
# 478   R_3JEPAzSSS7vl7m8     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17     (1.0, -1.0, 1.0, 2.0)
# 482   R_R9rAxbkMUkt1JD3     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17  (-2.0, -2.0, -3.0, -2.0)
# 483   R_2Ug3SEeklouMcjf     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17  (-2.0, -2.0, -2.0, -2.0)
# 484   R_0wWEN41ItvEhPq1     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17      (1.0, 1.0, 1.0, 1.0)
# 488   R_1diRg3FdvVeuFW3     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17     (0.0, 1.0, -2.0, 1.0)
# 489   R_x41neWaLb6waSPf     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17      (2.0, 2.0, 1.0, 1.0)
# 492   R_1FA0BdICJQM8hHO     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        17      (2.0, 2.0, 2.0, 2.0)
# 494   R_28J2ielzrCfvy71     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18      (3.0, 2.0, 1.0, 0.0)
# 496   R_1lsl8kCjFiBTyzK     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18    (-3.0, -3.0, 0.0, 0.0)
# 500   R_UfKVwc8Ysy6pN1n     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18      (2.0, 2.0, 2.0, 2.0)
# 501   R_1cTAX495KgNw4zW     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18  (-2.0, -1.0, -2.0, -1.0)
# 502   R_3hDv6lQBiaJSbmx     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18      (2.0, 2.0, 2.0, 3.0)
# 504   R_3JaYb1pOqZxJWjR     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18  (-1.0, -1.0, -1.0, -1.0)
# 505   R_4GvYKPN7O7VmLE5     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18      (2.0, 2.0, 2.0, 2.0)
# 506   R_BVzB1em5zins9Ed     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18      (2.0, 2.0, 2.0, 2.0)
# 507   R_3JEPAzSSS7vl7m8     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18     (1.0, -1.0, 1.0, 2.0)
# 511   R_R9rAxbkMUkt1JD3     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18  (-2.0, -2.0, -3.0, -2.0)
# 512   R_2Ug3SEeklouMcjf     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18  (-2.0, -2.0, -2.0, -2.0)
# 513   R_0wWEN41ItvEhPq1     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18      (1.0, 1.0, 1.0, 1.0)
# 517   R_1diRg3FdvVeuFW3     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18     (0.0, 1.0, -2.0, 1.0)
# 518   R_x41neWaLb6waSPf     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18      (2.0, 2.0, 1.0, 1.0)
# 521   R_1FA0BdICJQM8hHO     fixed-sidebar  no_right_sidebar_no_categorization  3-cupcakes        18      (2.0, 2.0, 2.0, 2.0)
# 522   R_1jg3libD6KGk9H6  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19      (1.0, 2.0, 0.0, 0.0)
# 524   R_1q1Bu2t44LidHJ7  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19      (1.0, 1.0, 2.0, 2.0)
# 526   R_2QuIZZlVUGCBNnT  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19   (-1.0, -1.0, -1.0, 0.0)
# 532   R_3r0MPrhyKAiN456  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19  (-3.0, -3.0, -3.0, -3.0)
# 538   R_pMA85t7Mv3uCvZv  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19  (-2.0, -1.0, -3.0, -2.0)
# 539   R_3lrDJAYNb7HdI4g  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19     (0.0, 0.0, -1.0, 0.0)
# 543   R_prv1eb7fdBytdwB  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19     (1.0, 1.0, -1.0, 1.0)
# 544   R_1rqdXQIUzMSPgaI  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19      (3.0, 3.0, 3.0, 3.0)
# 548   R_sFoJmEO3bd10x9f  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        19   (-1.0, -1.0, 0.0, -1.0)
# 551   R_1jg3libD6KGk9H6  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21      (1.0, 2.0, 0.0, 0.0)
# 553   R_1q1Bu2t44LidHJ7  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21      (1.0, 1.0, 2.0, 2.0)
# 555   R_2QuIZZlVUGCBNnT  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21   (-1.0, -1.0, -1.0, 0.0)
# 561   R_3r0MPrhyKAiN456  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21  (-3.0, -3.0, -3.0, -3.0)
# 567   R_pMA85t7Mv3uCvZv  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21  (-2.0, -1.0, -3.0, -2.0)
# 568   R_3lrDJAYNb7HdI4g  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21     (0.0, 0.0, -1.0, 0.0)
# 572   R_prv1eb7fdBytdwB  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21     (1.0, 1.0, -1.0, 1.0)
# 573   R_1rqdXQIUzMSPgaI  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21      (3.0, 3.0, 3.0, 3.0)
# 577   R_sFoJmEO3bd10x9f  floating-sidebar     right_sidebar_no_categorization  6-cupcakes        21   (-1.0, -1.0, 0.0, -1.0)
# 580   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  6-cupcakes        22      (1.0, 2.0, 1.0, 1.0)
# 582   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  6-cupcakes        22      (1.0, 2.0, 2.0, 2.0)
# 584   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  6-cupcakes        22   (-2.0, -2.0, -2.0, 0.0)
# 590   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  6-cupcakes        22  (-3.0, -3.0, -3.0, -3.0)
# 596   R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  6-cupcakes        22     (1.0, -1.0, 1.0, 1.0)
# 597   R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  6-cupcakes        22      (0.0, 0.0, 0.0, 0.0)
# 601   R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  6-cupcakes        22     (1.0, 1.0, -1.0, 1.0)
# 602   R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  6-cupcakes        22      (3.0, 3.0, 3.0, 3.0)
# 606   R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  6-cupcakes        22      (1.0, 1.0, 1.0, 1.0)
# 609   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  6-cupcakes        23      (1.0, 2.0, 1.0, 1.0)
# 611   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  6-cupcakes        23      (1.0, 2.0, 2.0, 2.0)
# 613   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  6-cupcakes        23   (-2.0, -2.0, -2.0, 0.0)
# 619   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  6-cupcakes        23  (-3.0, -3.0, -3.0, -3.0)
# 625   R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  6-cupcakes        23     (1.0, -1.0, 1.0, 1.0)
# 626   R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  6-cupcakes        23      (0.0, 0.0, 0.0, 0.0)
# 630   R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  6-cupcakes        23     (1.0, 1.0, -1.0, 1.0)
# 631   R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  6-cupcakes        23      (3.0, 3.0, 3.0, 3.0)
# 635   R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  6-cupcakes        23      (1.0, 1.0, 1.0, 1.0)
# 638   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  6-cupcakes        24      (1.0, 2.0, 1.0, 1.0)
# 640   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  6-cupcakes        24      (1.0, 2.0, 2.0, 2.0)
# 642   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  6-cupcakes        24   (-2.0, -2.0, -2.0, 0.0)
# 648   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  6-cupcakes        24  (-3.0, -3.0, -3.0, -3.0)
# 654   R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  6-cupcakes        24     (1.0, -1.0, 1.0, 1.0)
# 655   R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  6-cupcakes        24      (0.0, 0.0, 0.0, 0.0)
# 659   R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  6-cupcakes        24     (1.0, 1.0, -1.0, 1.0)
# 660   R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  6-cupcakes        24      (3.0, 3.0, 3.0, 3.0)
# 664   R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  6-cupcakes        24      (1.0, 1.0, 1.0, 1.0)
# 667   R_1jg3libD6KGk9H6  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25     (1.0, 2.0, -1.0, 0.0)
# 669   R_1q1Bu2t44LidHJ7  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25      (1.0, 1.0, 1.0, 2.0)
# 671   R_2QuIZZlVUGCBNnT  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25   (-2.0, -2.0, -2.0, 0.0)
# 677   R_3r0MPrhyKAiN456  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25  (-1.0, -1.0, -1.0, -1.0)
# 683   R_pMA85t7Mv3uCvZv  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25  (-2.0, -3.0, -3.0, -1.0)
# 684   R_3lrDJAYNb7HdI4g  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25      (0.0, 0.0, 0.0, 0.0)
# 688   R_prv1eb7fdBytdwB  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25     (1.0, 1.0, -1.0, 1.0)
# 689   R_1rqdXQIUzMSPgaI  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25      (3.0, 3.0, 3.0, 3.0)
# 693   R_sFoJmEO3bd10x9f  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        25      (0.0, 0.0, 0.0, 0.0)
# 696   R_1jg3libD6KGk9H6  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26     (1.0, 2.0, -1.0, 0.0)
# 698   R_1q1Bu2t44LidHJ7  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26      (1.0, 1.0, 1.0, 2.0)
# 700   R_2QuIZZlVUGCBNnT  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26   (-2.0, -2.0, -2.0, 0.0)
# 706   R_3r0MPrhyKAiN456  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26  (-1.0, -1.0, -1.0, -1.0)
# 712   R_pMA85t7Mv3uCvZv  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26  (-2.0, -3.0, -3.0, -1.0)
# 713   R_3lrDJAYNb7HdI4g  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26      (0.0, 0.0, 0.0, 0.0)
# 717   R_prv1eb7fdBytdwB  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26     (1.0, 1.0, -1.0, 1.0)
# 718   R_1rqdXQIUzMSPgaI  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26      (3.0, 3.0, 3.0, 3.0)
# 722   R_sFoJmEO3bd10x9f  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        26      (0.0, 0.0, 0.0, 0.0)
# 725   R_1jg3libD6KGk9H6  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27     (1.0, 2.0, -1.0, 0.0)
# 727   R_1q1Bu2t44LidHJ7  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27      (1.0, 1.0, 1.0, 2.0)
# 729   R_2QuIZZlVUGCBNnT  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27   (-2.0, -2.0, -2.0, 0.0)
# 735   R_3r0MPrhyKAiN456  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27  (-1.0, -1.0, -1.0, -1.0)
# 741   R_pMA85t7Mv3uCvZv  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27  (-2.0, -3.0, -3.0, -1.0)
# 742   R_3lrDJAYNb7HdI4g  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27      (0.0, 0.0, 0.0, 0.0)
# 746   R_prv1eb7fdBytdwB  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27     (1.0, 1.0, -1.0, 1.0)
# 747   R_1rqdXQIUzMSPgaI  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27      (3.0, 3.0, 3.0, 3.0)
# 751   R_sFoJmEO3bd10x9f  floating-sidebar  no_right_sidebar_no_categorization  6-cupcakes        27      (0.0, 0.0, 0.0, 0.0)
# 754   R_1jg3libD6KGk9H6  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28      (2.0, 1.0, 2.0, 2.0)
# 756   R_1q1Bu2t44LidHJ7  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28     (-1.0, 2.0, 1.0, 2.0)
# 758   R_2QuIZZlVUGCBNnT  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28      (0.0, 0.0, 0.0, 0.0)
# 764   R_3r0MPrhyKAiN456  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28  (-1.0, -1.0, -1.0, -1.0)
# 770   R_pMA85t7Mv3uCvZv  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28   (1.0, -1.0, -1.0, -1.0)
# 771   R_3lrDJAYNb7HdI4g  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28      (0.0, 0.0, 0.0, 0.0)
# 775   R_prv1eb7fdBytdwB  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28     (1.0, 1.0, -1.0, 1.0)
# 776   R_1rqdXQIUzMSPgaI  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28      (2.0, 2.0, 2.0, 2.0)
# 780   R_sFoJmEO3bd10x9f  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        28  (-2.0, -2.0, -2.0, -2.0)
# 783   R_1jg3libD6KGk9H6  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29      (2.0, 1.0, 2.0, 2.0)
# 785   R_1q1Bu2t44LidHJ7  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29     (-1.0, 2.0, 1.0, 2.0)
# 787   R_2QuIZZlVUGCBNnT  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29      (0.0, 0.0, 0.0, 0.0)
# 793   R_3r0MPrhyKAiN456  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29  (-1.0, -1.0, -1.0, -1.0)
# 799   R_pMA85t7Mv3uCvZv  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29   (1.0, -1.0, -1.0, -1.0)
# 800   R_3lrDJAYNb7HdI4g  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29      (0.0, 0.0, 0.0, 0.0)
# 804   R_prv1eb7fdBytdwB  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29     (1.0, 1.0, -1.0, 1.0)
# 805   R_1rqdXQIUzMSPgaI  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29      (2.0, 2.0, 2.0, 2.0)
# 809   R_sFoJmEO3bd10x9f  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        29  (-2.0, -2.0, -2.0, -2.0)
# 812   R_1jg3libD6KGk9H6  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30      (2.0, 1.0, 2.0, 2.0)
# 814   R_1q1Bu2t44LidHJ7  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30     (-1.0, 2.0, 1.0, 2.0)
# 816   R_2QuIZZlVUGCBNnT  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30      (0.0, 0.0, 0.0, 0.0)
# 822   R_3r0MPrhyKAiN456  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30  (-1.0, -1.0, -1.0, -1.0)
# 828   R_pMA85t7Mv3uCvZv  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30   (1.0, -1.0, -1.0, -1.0)
# 829   R_3lrDJAYNb7HdI4g  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30      (0.0, 0.0, 0.0, 0.0)
# 833   R_prv1eb7fdBytdwB  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30     (1.0, 1.0, -1.0, 1.0)
# 834   R_1rqdXQIUzMSPgaI  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30      (2.0, 2.0, 2.0, 2.0)
# 838   R_sFoJmEO3bd10x9f  floating-sidebar     right_sidebar_no_categorization  3-cupcakes        30  (-2.0, -2.0, -2.0, -2.0)
# 841   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  3-cupcakes        31      (2.0, 3.0, 3.0, 3.0)
# 843   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  3-cupcakes        31     (-1.0, 2.0, 1.0, 2.0)
# 845   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  3-cupcakes        31      (0.0, 0.0, 0.0, 0.0)
# 851   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  3-cupcakes        31  (-1.0, -1.0, -1.0, -1.0)
# 857   R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  3-cupcakes        31      (2.0, 2.0, 3.0, 3.0)
# 858   R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  3-cupcakes        31      (1.0, 0.0, 1.0, 1.0)
# 862   R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  3-cupcakes        31     (1.0, 1.0, -1.0, 1.0)
# 863   R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  3-cupcakes        31     (1.0, -1.0, 2.0, 2.0)
# 867   R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  3-cupcakes        31  (-2.0, -2.0, -2.0, -2.0)
# 870   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  3-cupcakes        32      (2.0, 3.0, 3.0, 3.0)
# 872   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  3-cupcakes        32     (-1.0, 2.0, 1.0, 2.0)
# 874   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  3-cupcakes        32      (0.0, 0.0, 0.0, 0.0)
# 880   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  3-cupcakes        32  (-1.0, -1.0, -1.0, -1.0)
# 886   R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  3-cupcakes        32      (2.0, 2.0, 3.0, 3.0)
# 887   R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  3-cupcakes        32      (1.0, 0.0, 1.0, 1.0)
# 891   R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  3-cupcakes        32     (1.0, 1.0, -1.0, 1.0)
# 892   R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  3-cupcakes        32     (1.0, -1.0, 2.0, 2.0)
# 896   R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  3-cupcakes        32  (-2.0, -2.0, -2.0, -2.0)
# 899   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  3-cupcakes        33      (2.0, 3.0, 3.0, 3.0)
# 901   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  3-cupcakes        33     (-1.0, 2.0, 1.0, 2.0)
# 903   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  3-cupcakes        33      (0.0, 0.0, 0.0, 0.0)
# 909   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  3-cupcakes        33  (-1.0, -1.0, -1.0, -1.0)
# 915   R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  3-cupcakes        33      (2.0, 2.0, 3.0, 3.0)
# 916   R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  3-cupcakes        33      (1.0, 0.0, 1.0, 1.0)
# 920   R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  3-cupcakes        33     (1.0, 1.0, -1.0, 1.0)
# 921   R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  3-cupcakes        33     (1.0, -1.0, 2.0, 2.0)
# 925   R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  3-cupcakes        33  (-2.0, -2.0, -2.0, -2.0)
# 928   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  3-cupcakes        34      (2.0, 1.0, 2.0, 1.0)
# 930   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  3-cupcakes        34      (0.0, 1.0, 2.0, 1.0)
# 932   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  3-cupcakes        34      (0.0, 0.0, 0.0, 0.0)
# 938   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  3-cupcakes        34  (-1.0, -1.0, -1.0, -1.0)
# 944   R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  3-cupcakes        34    (-1.0, -1.0, 1.0, 1.0)
# 945   R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  3-cupcakes        34     (0.0, -1.0, 0.0, 0.0)
# 949   R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  3-cupcakes        34     (1.0, 1.0, -1.0, 1.0)
# 950   R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  3-cupcakes        34      (2.0, 2.0, 2.0, 2.0)
# 954   R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  3-cupcakes        34  (-1.0, -1.0, -1.0, -1.0)
# 957   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  3-cupcakes        35      (2.0, 1.0, 2.0, 1.0)
# 959   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  3-cupcakes        35      (0.0, 1.0, 2.0, 1.0)
# 961   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  3-cupcakes        35      (0.0, 0.0, 0.0, 0.0)
# 967   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  3-cupcakes        35  (-1.0, -1.0, -1.0, -1.0)
# 973   R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  3-cupcakes        35    (-1.0, -1.0, 1.0, 1.0)
# 974   R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  3-cupcakes        35     (0.0, -1.0, 0.0, 0.0)
# 978   R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  3-cupcakes        35     (1.0, 1.0, -1.0, 1.0)
# 979   R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  3-cupcakes        35      (2.0, 2.0, 2.0, 2.0)
# 983   R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  3-cupcakes        35  (-1.0, -1.0, -1.0, -1.0)
# 986   R_1jg3libD6KGk9H6  floating-sidebar        right_sidebar_categorization  3-cupcakes        36      (2.0, 1.0, 2.0, 1.0)
# 988   R_1q1Bu2t44LidHJ7  floating-sidebar        right_sidebar_categorization  3-cupcakes        36      (0.0, 1.0, 2.0, 1.0)
# 990   R_2QuIZZlVUGCBNnT  floating-sidebar        right_sidebar_categorization  3-cupcakes        36      (0.0, 0.0, 0.0, 0.0)
# 996   R_3r0MPrhyKAiN456  floating-sidebar        right_sidebar_categorization  3-cupcakes        36  (-1.0, -1.0, -1.0, -1.0)
# 1002  R_pMA85t7Mv3uCvZv  floating-sidebar        right_sidebar_categorization  3-cupcakes        36    (-1.0, -1.0, 1.0, 1.0)
# 1003  R_3lrDJAYNb7HdI4g  floating-sidebar        right_sidebar_categorization  3-cupcakes        36     (0.0, -1.0, 0.0, 0.0)
# 1007  R_prv1eb7fdBytdwB  floating-sidebar        right_sidebar_categorization  3-cupcakes        36     (1.0, 1.0, -1.0, 1.0)
# 1008  R_1rqdXQIUzMSPgaI  floating-sidebar        right_sidebar_categorization  3-cupcakes        36      (2.0, 2.0, 2.0, 2.0)
# 1012  R_sFoJmEO3bd10x9f  floating-sidebar        right_sidebar_categorization  3-cupcakes        36  (-1.0, -1.0, -1.0, -1.0)

# %% [markdown]
# ### Drop some more unused columns

# %%
df3 = df3.drop(["pri_exp","buy_check"], axis=1)

# %% [markdown]
# ### List of final columns

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423 entries, 1 to 1012
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ResponseId               423 non-null    object
#  1   age_group                423 non-null    object
#  2   gender                   423 non-null    object
#  3   computer_use_confide     423 non-null    object
#  4   sweet_food_affinity      423 non-null    object
#  5   computer_os              423 non-null    object
#  6   sidebar_rating           423 non-null    float64
#  7   categorization_rating    423 non-null    float64
#  8   category_sidebar_rating  423 non-null    float64
#  9   IV1                      423 non-null    object
#  10  arrangement              423 non-null    object
#  11  ecomm_frequence          423 non-null    object
#  12  trial_id                 423 non-null    int32
#  13  ease_of_use              423 non-null    object
#  14  IV2                      423 non-null    object
#  15  IV3                      423 non-null    object
# dtypes: float64(3), int32(1), object(12)
# memory usage: 54.5+ KB

# %% [markdown]
# ### First 5 rows in cleaned data

# %%
df3.head()
# Out:
#           ResponseId age_group gender computer_use_confide  \
# 1  R_28J2ielzrCfvy71         2      1                    3
# 3  R_1lsl8kCjFiBTyzK         2      1                    3
# 7  R_UfKVwc8Ysy6pN1n         2      2                    2
# 8  R_1cTAX495KgNw4zW         2      1                    2
# 9  R_3hDv6lQBiaJSbmx         2      2                    3
#
#   sweet_food_affinity computer_os  sidebar_rating  categorization_rating  \
# 1                  -1           1             7.0                    6.0
# 3                   3           1             7.0                    7.0
# 7                   2           1             7.0                    3.0
# 8                  -1           1             6.0                    5.0
# 9                   1           1             6.0                    5.0
#
#    category_sidebar_rating            IV1 arrangement ecomm_frequence  \
# 1                      5.0  fixed-sidebar           3               2
# 3                      7.0  fixed-sidebar           6               2
# 7                      2.0  fixed-sidebar           3               2
# 8                      7.0  fixed-sidebar           6               3
# 9                      5.0  fixed-sidebar           2               1
#
#    trial_id            ease_of_use                              IV2  \
# 1         1   (0.0, 1.0, 2.0, 3.0)  right_sidebar_no_categorization
# 3         1   (3.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 7         1   (2.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 8         1   (1.0, 2.0, 2.0, 1.0)  right_sidebar_no_categorization
# 9         1  (2.0, 2.0, -1.0, 3.0)  right_sidebar_no_categorization
#
#           IV3
# 1  6-cupcakes
# 3  6-cupcakes
# 7  6-cupcakes
# 8  6-cupcakes
# 9  6-cupcakes

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423 entries, 1 to 1012
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ResponseId               423 non-null    object
#  1   age_group                423 non-null    object
#  2   gender                   423 non-null    object
#  3   computer_use_confide     423 non-null    object
#  4   sweet_food_affinity      423 non-null    object
#  5   computer_os              423 non-null    object
#  6   sidebar_rating           423 non-null    float64
#  7   categorization_rating    423 non-null    float64
#  8   category_sidebar_rating  423 non-null    float64
#  9   IV1                      423 non-null    object
#  10  arrangement              423 non-null    object
#  11  ecomm_frequence          423 non-null    object
#  12  trial_id                 423 non-null    int32
#  13  ease_of_use              423 non-null    object
#  14  IV2                      423 non-null    object
#  15  IV3                      423 non-null    object
# dtypes: float64(3), int32(1), object(12)
# memory usage: 54.5+ KB

# %% [markdown]
# ### Recode values in age group

# %%
df3.age_group.unique()
# Out:
# array(['2'], dtype=object)

# %%
df3["age_group"] = df3["age_group"].replace(["1","2","3","4"], ["less than 20", "between 20 and 30", "between 30 and 40","more than 40"])

# %%
df3.head()
# Out:
#           ResponseId          age_group gender computer_use_confide  \
# 1  R_28J2ielzrCfvy71  between 20 and 30      1                    3
# 3  R_1lsl8kCjFiBTyzK  between 20 and 30      1                    3
# 7  R_UfKVwc8Ysy6pN1n  between 20 and 30      2                    2
# 8  R_1cTAX495KgNw4zW  between 20 and 30      1                    2
# 9  R_3hDv6lQBiaJSbmx  between 20 and 30      2                    3
#
#   sweet_food_affinity computer_os  sidebar_rating  categorization_rating  \
# 1                  -1           1             7.0                    6.0
# 3                   3           1             7.0                    7.0
# 7                   2           1             7.0                    3.0
# 8                  -1           1             6.0                    5.0
# 9                   1           1             6.0                    5.0
#
#    category_sidebar_rating            IV1 arrangement ecomm_frequence  \
# 1                      5.0  fixed-sidebar           3               2
# 3                      7.0  fixed-sidebar           6               2
# 7                      2.0  fixed-sidebar           3               2
# 8                      7.0  fixed-sidebar           6               3
# 9                      5.0  fixed-sidebar           2               1
#
#    trial_id            ease_of_use                              IV2  \
# 1         1   (0.0, 1.0, 2.0, 3.0)  right_sidebar_no_categorization
# 3         1   (3.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 7         1   (2.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 8         1   (1.0, 2.0, 2.0, 1.0)  right_sidebar_no_categorization
# 9         1  (2.0, 2.0, -1.0, 3.0)  right_sidebar_no_categorization
#
#           IV3
# 1  6-cupcakes
# 3  6-cupcakes
# 7  6-cupcakes
# 8  6-cupcakes
# 9  6-cupcakes

# %% [markdown]
# ### Recode gender

# %%
df3["gender"] = df3["gender"].replace(["1","2","3","4"], ["Male", "Female", "Non-binary","Unspecified"])

# %%
df3.head()
# Out:
#           ResponseId          age_group  gender computer_use_confide  \
# 1  R_28J2ielzrCfvy71  between 20 and 30    Male                    3
# 3  R_1lsl8kCjFiBTyzK  between 20 and 30    Male                    3
# 7  R_UfKVwc8Ysy6pN1n  between 20 and 30  Female                    2
# 8  R_1cTAX495KgNw4zW  between 20 and 30    Male                    2
# 9  R_3hDv6lQBiaJSbmx  between 20 and 30  Female                    3
#
#   sweet_food_affinity computer_os  sidebar_rating  categorization_rating  \
# 1                  -1           1             7.0                    6.0
# 3                   3           1             7.0                    7.0
# 7                   2           1             7.0                    3.0
# 8                  -1           1             6.0                    5.0
# 9                   1           1             6.0                    5.0
#
#    category_sidebar_rating            IV1 arrangement ecomm_frequence  \
# 1                      5.0  fixed-sidebar           3               2
# 3                      7.0  fixed-sidebar           6               2
# 7                      2.0  fixed-sidebar           3               2
# 8                      7.0  fixed-sidebar           6               3
# 9                      5.0  fixed-sidebar           2               1
#
#    trial_id            ease_of_use                              IV2  \
# 1         1   (0.0, 1.0, 2.0, 3.0)  right_sidebar_no_categorization
# 3         1   (3.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 7         1   (2.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 8         1   (1.0, 2.0, 2.0, 1.0)  right_sidebar_no_categorization
# 9         1  (2.0, 2.0, -1.0, 3.0)  right_sidebar_no_categorization
#
#           IV3
# 1  6-cupcakes
# 3  6-cupcakes
# 7  6-cupcakes
# 8  6-cupcakes
# 9  6-cupcakes

# %% [markdown]
# ### Recode computer OS

# %%
df3["computer_os"] = df3["computer_os"].replace(["1","2","4"], ["macOs", "Windows", "Other"])

# %%
df3.head()
# Out:
#           ResponseId          age_group  gender computer_use_confide  \
# 1  R_28J2ielzrCfvy71  between 20 and 30    Male                    3
# 3  R_1lsl8kCjFiBTyzK  between 20 and 30    Male                    3
# 7  R_UfKVwc8Ysy6pN1n  between 20 and 30  Female                    2
# 8  R_1cTAX495KgNw4zW  between 20 and 30    Male                    2
# 9  R_3hDv6lQBiaJSbmx  between 20 and 30  Female                    3
#
#   sweet_food_affinity computer_os  sidebar_rating  categorization_rating  \
# 1                  -1       macOs             7.0                    6.0
# 3                   3       macOs             7.0                    7.0
# 7                   2       macOs             7.0                    3.0
# 8                  -1       macOs             6.0                    5.0
# 9                   1       macOs             6.0                    5.0
#
#    category_sidebar_rating            IV1 arrangement ecomm_frequence  \
# 1                      5.0  fixed-sidebar           3               2
# 3                      7.0  fixed-sidebar           6               2
# 7                      2.0  fixed-sidebar           3               2
# 8                      7.0  fixed-sidebar           6               3
# 9                      5.0  fixed-sidebar           2               1
#
#    trial_id            ease_of_use                              IV2  \
# 1         1   (0.0, 1.0, 2.0, 3.0)  right_sidebar_no_categorization
# 3         1   (3.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 7         1   (2.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 8         1   (1.0, 2.0, 2.0, 1.0)  right_sidebar_no_categorization
# 9         1  (2.0, 2.0, -1.0, 3.0)  right_sidebar_no_categorization
#
#           IV3
# 1  6-cupcakes
# 3  6-cupcakes
# 7  6-cupcakes
# 8  6-cupcakes
# 9  6-cupcakes

# %% [markdown]
# ### Recode computer use confidence

# %%
df3["computer_use_confide"] = df3["computer_use_confide"].replace(["-3","-2","-1","0","1","2","3"], ["Not at all confident", "Not confident", "Somewhat not confident","Neither confident nor uncofident","Somewhat confident","Confident","Very confident"])

# %%
df3.head()
# Out:
#           ResponseId          age_group  gender computer_use_confide  \
# 1  R_28J2ielzrCfvy71  between 20 and 30    Male       Very confident
# 3  R_1lsl8kCjFiBTyzK  between 20 and 30    Male       Very confident
# 7  R_UfKVwc8Ysy6pN1n  between 20 and 30  Female            Confident
# 8  R_1cTAX495KgNw4zW  between 20 and 30    Male            Confident
# 9  R_3hDv6lQBiaJSbmx  between 20 and 30  Female       Very confident
#
#   sweet_food_affinity computer_os  sidebar_rating  categorization_rating  \
# 1                  -1       macOs             7.0                    6.0
# 3                   3       macOs             7.0                    7.0
# 7                   2       macOs             7.0                    3.0
# 8                  -1       macOs             6.0                    5.0
# 9                   1       macOs             6.0                    5.0
#
#    category_sidebar_rating            IV1 arrangement ecomm_frequence  \
# 1                      5.0  fixed-sidebar           3               2
# 3                      7.0  fixed-sidebar           6               2
# 7                      2.0  fixed-sidebar           3               2
# 8                      7.0  fixed-sidebar           6               3
# 9                      5.0  fixed-sidebar           2               1
#
#    trial_id            ease_of_use                              IV2  \
# 1         1   (0.0, 1.0, 2.0, 3.0)  right_sidebar_no_categorization
# 3         1   (3.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 7         1   (2.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 8         1   (1.0, 2.0, 2.0, 1.0)  right_sidebar_no_categorization
# 9         1  (2.0, 2.0, -1.0, 3.0)  right_sidebar_no_categorization
#
#           IV3
# 1  6-cupcakes
# 3  6-cupcakes
# 7  6-cupcakes
# 8  6-cupcakes
# 9  6-cupcakes

# %% [markdown]
# ### Recode affinity to sweet foods

# %%
df3["sweet_food_affinity"] = df3["sweet_food_affinity"].replace(["-3","-2","-1","0","1","2","3"], ["Strongly dislike", "Dislike", "Somewhat dislike","Neither like nor dislike","Somewhat like","Like","Like a lot"])

# %%
df3.head()
# Out:
#           ResponseId          age_group  gender computer_use_confide  \
# 1  R_28J2ielzrCfvy71  between 20 and 30    Male       Very confident
# 3  R_1lsl8kCjFiBTyzK  between 20 and 30    Male       Very confident
# 7  R_UfKVwc8Ysy6pN1n  between 20 and 30  Female            Confident
# 8  R_1cTAX495KgNw4zW  between 20 and 30    Male            Confident
# 9  R_3hDv6lQBiaJSbmx  between 20 and 30  Female       Very confident
#
#   sweet_food_affinity computer_os  sidebar_rating  categorization_rating  \
# 1    Somewhat dislike       macOs             7.0                    6.0
# 3          Like a lot       macOs             7.0                    7.0
# 7                Like       macOs             7.0                    3.0
# 8    Somewhat dislike       macOs             6.0                    5.0
# 9       Somewhat like       macOs             6.0                    5.0
#
#    category_sidebar_rating            IV1 arrangement ecomm_frequence  \
# 1                      5.0  fixed-sidebar           3               2
# 3                      7.0  fixed-sidebar           6               2
# 7                      2.0  fixed-sidebar           3               2
# 8                      7.0  fixed-sidebar           6               3
# 9                      5.0  fixed-sidebar           2               1
#
#    trial_id            ease_of_use                              IV2  \
# 1         1   (0.0, 1.0, 2.0, 3.0)  right_sidebar_no_categorization
# 3         1   (3.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 7         1   (2.0, 1.0, 1.0, 1.0)  right_sidebar_no_categorization
# 8         1   (1.0, 2.0, 2.0, 1.0)  right_sidebar_no_categorization
# 9         1  (2.0, 2.0, -1.0, 3.0)  right_sidebar_no_categorization
#
#           IV3
# 1  6-cupcakes
# 3  6-cupcakes
# 7  6-cupcakes
# 8  6-cupcakes
# 9  6-cupcakes

# %% [markdown]
# ### Recode ecommerce use frequency

# %%
df3["ecomm_frequence"] = df3["ecomm_frequence"].replace(["1","2","3"], ["Last purchased within 1 week", "Last purchased between 1 week and 1 month", "Last purchansed more than 1 month ago"])

# %%
df3.head()
# Out:
#           ResponseId          age_group  gender computer_use_confide  \
# 1  R_28J2ielzrCfvy71  between 20 and 30    Male       Very confident
# 3  R_1lsl8kCjFiBTyzK  between 20 and 30    Male       Very confident
# 7  R_UfKVwc8Ysy6pN1n  between 20 and 30  Female            Confident
# 8  R_1cTAX495KgNw4zW  between 20 and 30    Male            Confident
# 9  R_3hDv6lQBiaJSbmx  between 20 and 30  Female       Very confident
#
#   sweet_food_affinity computer_os  sidebar_rating  categorization_rating  \
# 1    Somewhat dislike       macOs             7.0                    6.0
# 3          Like a lot       macOs             7.0                    7.0
# 7                Like       macOs             7.0                    3.0
# 8    Somewhat dislike       macOs             6.0                    5.0
# 9       Somewhat like       macOs             6.0                    5.0
#
#    category_sidebar_rating            IV1 arrangement  \
# 1                      5.0  fixed-sidebar           3
# 3                      7.0  fixed-sidebar           6
# 7                      2.0  fixed-sidebar           3
# 8                      7.0  fixed-sidebar           6
# 9                      5.0  fixed-sidebar           2
#
#                              ecomm_frequence  trial_id            ease_of_use  \
# 1  Last purchased between 1 week and 1 month         1   (0.0, 1.0, 2.0, 3.0)
# 3  Last purchased between 1 week and 1 month         1   (3.0, 1.0, 1.0, 1.0)
# 7  Last purchased between 1 week and 1 month         1   (2.0, 1.0, 1.0, 1.0)
# 8      Last purchansed more than 1 month ago         1   (1.0, 2.0, 2.0, 1.0)
# 9               Last purchased within 1 week         1  (2.0, 2.0, -1.0, 3.0)
#
#                                IV2         IV3
# 1  right_sidebar_no_categorization  6-cupcakes
# 3  right_sidebar_no_categorization  6-cupcakes
# 7  right_sidebar_no_categorization  6-cupcakes
# 8  right_sidebar_no_categorization  6-cupcakes
# 9  right_sidebar_no_categorization  6-cupcakes

# %% [markdown]
# ### Split ease of use values

# %%
def process_ease_of_use(row, index):
    return row.ease_of_use[index]

# %%
df3["ease_of_use_task_completion"] = df3.apply(lambda row: process_ease_of_use(row,0), axis=1)
df3["ease_of_use_navigate_to_browsing"] = df3.apply(lambda row: process_ease_of_use(row,1), axis=1)
df3["ease_of_use_find_cupcake"] = df3.apply(lambda row: process_ease_of_use(row,2), axis=1)
df3["ease_of_use_total_time"] = df3.apply(lambda row: process_ease_of_use(row,3), axis=1)
df3 = df3.drop(["ease_of_use"], axis=1)

# %%
df3.head()
# Out:
#           ResponseId          age_group  gender computer_use_confide  \
# 1  R_28J2ielzrCfvy71  between 20 and 30    Male       Very confident
# 3  R_1lsl8kCjFiBTyzK  between 20 and 30    Male       Very confident
# 7  R_UfKVwc8Ysy6pN1n  between 20 and 30  Female            Confident
# 8  R_1cTAX495KgNw4zW  between 20 and 30    Male            Confident
# 9  R_3hDv6lQBiaJSbmx  between 20 and 30  Female       Very confident
#
#   sweet_food_affinity computer_os  sidebar_rating  categorization_rating  \
# 1    Somewhat dislike       macOs             7.0                    6.0
# 3          Like a lot       macOs             7.0                    7.0
# 7                Like       macOs             7.0                    3.0
# 8    Somewhat dislike       macOs             6.0                    5.0
# 9       Somewhat like       macOs             6.0                    5.0
#
#    category_sidebar_rating            IV1 arrangement  \
# 1                      5.0  fixed-sidebar           3
# 3                      7.0  fixed-sidebar           6
# 7                      2.0  fixed-sidebar           3
# 8                      7.0  fixed-sidebar           6
# 9                      5.0  fixed-sidebar           2
#
#                              ecomm_frequence  trial_id  \
# 1  Last purchased between 1 week and 1 month         1
# 3  Last purchased between 1 week and 1 month         1
# 7  Last purchased between 1 week and 1 month         1
# 8      Last purchansed more than 1 month ago         1
# 9               Last purchased within 1 week         1
#
#                                IV2         IV3  ease_of_use_task_completion  \
# 1  right_sidebar_no_categorization  6-cupcakes                          0.0
# 3  right_sidebar_no_categorization  6-cupcakes                          3.0
# 7  right_sidebar_no_categorization  6-cupcakes                          2.0
# 8  right_sidebar_no_categorization  6-cupcakes                          1.0
# 9  right_sidebar_no_categorization  6-cupcakes                          2.0
#
#    ease_of_use_navigate_to_browsing  ease_of_use_find_cupcake  \
# 1                               1.0                       2.0
# 3                               1.0                       1.0
# 7                               1.0                       1.0
# 8                               2.0                       2.0
# 9                               2.0                      -1.0
#
#    ease_of_use_total_time
# 1                     3.0
# 3                     1.0
# 7                     1.0
# 8                     1.0
# 9                     3.0

# %% [markdown]
# ### Save data to csv

# %%
df3.to_csv("qualtrics_data_cleaned.csv", index=False)
